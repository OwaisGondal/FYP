# %%
import re
import time

import bs4 as bs
import firebase_admin
import pandas as pd
from firebase_admin import credentials, firestore
from selenium import webdriver

# %% [markdown]
# #### Firebase Credentials

# %%
cred = credentials.Certificate(
    "C://Users/OwaisGondal/Documents/Python/FYP/TestKey.json"
)
firebase_admin.initialize_app(cred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-d1df0a526749> in <module>
#       2     "C://Users/OwaisGondal/Documents/Python/FYP/TestKey.json"
#       3 )
# ----> 4 firebase_admin.initialize_app(cred)
#
# ~\Anaconda3\lib\site-packages\firebase_admin\__init__.py in initialize_app(credential, options, name)
#      69
#      70     if name == _DEFAULT_APP_NAME:
# ---> 71         raise ValueError((
#      72             'The default Firebase app already exists. This means you called '
#      73             'initialize_app() more than once without providing an app name as '
#
# ...

# %% [markdown]
# #### Connect to Firebase

# %%
db = firestore.client()  # this connects to Firestore

# %% [markdown]
# #### Chrome Webdriver

# %%
url = "https://www.whatmobile.com.pk/"
driver = webdriver.Chrome(
    "C:/Users/OwaisGondal/Downloads/Compressed/chromedriver_win32/chromedriver.exe"
)
driver.get(url)

# %% [markdown]
# #### Scraping

# %%
BrandKeys = []
BrandValues = []
for i in range(1, 35):
    #     print('//*[@id="container"]/div[3]/div/div[2]/section[2]/ul/li['+str(i)+"]/a")
    BrandKeys.append(
        driver.find_element_by_xpath(
            '//*[@id="container"]/div[3]/div/div[2]/section[2]/ul/li[' + str(i) + "]/a"
        ).text
    )
    BrandValues.append(
        driver.find_element_by_xpath(
            '//*[@id="container"]/div[3]/div/div[2]/section[2]/ul/li[' + str(i) + "]/a"
        ).get_attribute("href")
    )

# %%
Brands = dict(zip(BrandKeys, BrandValues))
Brands
# Out:
# {'Samsung Mobile': 'https://www.whatmobile.com.pk/Samsung_Mobiles_Prices',
#  'Huawei Mobile': 'https://www.whatmobile.com.pk/Huawei_Mobiles_Prices',
#  'Vivo': 'https://www.whatmobile.com.pk/Vivo_Mobiles_Prices',
#  'Honor Mobile': 'https://www.whatmobile.com.pk/Honor_Mobiles_Prices',
#  'OPPO Mobile': 'https://www.whatmobile.com.pk/Oppo_Mobiles_Prices',
#  'Realme Mobile': 'https://www.whatmobile.com.pk/Realme_Mobiles_Prices',
#  'Nokia': 'https://www.whatmobile.com.pk/Nokia_Mobiles_Prices',
#  'Xiaomi Mobile': 'https://www.whatmobile.com.pk/Xiaomi_Mobiles_Prices',
#  'Infinix Mobile': 'https://www.whatmobile.com.pk/Infinix_Mobiles_Prices',
#  'Apple iphone': 'https://www.whatmobile.com.pk/Apple_Mobiles_Prices',
#  'Tecno Mobile': 'https://www.whatmobile.com.pk/Tecno_Mobiles_Prices',
#  'QMobile': 'https://www.whatmobile.com.pk/Qmobile_Mobiles_Prices',
#  'Lenovo Mobile': 'https://www.whatmobile.com.pk/Lenovo_Mobiles_Prices',
# ...

# %%
driver.get(Brands["Samsung Mobile"])

# %%
# BrandDict=dict()
# BrandDict['Alcatel']={}
# BrandDict['Apple']={}
# BrandDict['Calme']={}
# BrandDict['GFive']={}
# BrandDict['HTC']={}
# BrandDict['Huawei']={}
# BrandDict['Infinix']={}
# BrandDict['LG']={}
# BrandDict['Lenovo']={}
# BrandDict['Motorola']={}
# BrandDict['Nokia']={}
# BrandDict['OnePlus']={}
# BrandDict['Oppo']={}
# BrandDict['Other']={}
# BrandDict['Qmobile']={}
# BrandDict['Realme']={}
# BrandDict['Samsung']={}
# BrandDict['Sony']={}
# BrandDict['Tecno']={}
# BrandDict['Telenor']={}
# BrandDict['Vivo']={}
# BrandDict['Xiaomi']={}

# %%
driver.get(Brands["Samsung Mobile"])
Phone = None
Phones = []
DataFrames = pd.DataFrame()
for i in range(1, 110):

    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[4]/div[' + str(i) + "]/div/h4/a"
        )
        Phones.append(Phone)
    except:
        1 == 1
for j in range(len(Phones)):
    df = pd.read_html(Phones[j].get_attribute("href"))
    new = df[0]
    new.insert(0, "Phone", Phones[j].text, True)
    new.set_index(["Phone", 0, 1], inplace=True)
    #     new.drop(columns=[3], inplace=True)
    DataFrames.append(new)
    print(new)
Phones.clear()
# Out:
#                                                                                                       2  \
# Phone                    0            1
# Samsung\nGalaxy Z Fold 2 Build        OS                                                  Android 10 OS
#                                       UI                                                     One UI 2.1
#                                       Dimensions      Unfolded: (159.2 x 128.2 x 6.9 mm), Folded: (1...
#                                       Weight                                                      279 g
#                                       SIM                             Dual Sim, Dual Standby (Nano-SIM)
#                                       Colors                                Mystic Black, Mystic Bronze
#                          Frequency    2G Band         SIM1: GSM 850 / 900 / 1800 / 1900SIM2: GSM 850...
#                                       3G Band                 HSDPA 850 / 900 / 1700(AWS) / 1900 / 2100
# ...

# %%
Phones = dict()
Phone = None

for key in Brands:
    Phones[key.split(" ")[0]] = {}
Phones
# Out:
# {'Samsung': {},
#  'Huawei': {},
#  'Vivo': {},
#  'Honor': {},
#  'OPPO': {},
#  'Realme': {},
#  'Nokia': {},
#  'Xiaomi': {},
#  'Infinix': {},
#  'Apple': {},
#  'Tecno': {},
#  'QMobile': {},
#  'Lenovo': {},
#  'Sony': {},
#  'LG': {},
#  'itel': {},
#  'OnePlus': {},
#  'Telenor': {},
#  'Alcatel': {},
#  'HTC': {},
#  'Microsoft': {},
#  'Rivo': {},
#  'Haier': {},
#  'Mobilink': {},
#  'Motorola': {},
#  'BlackBerry': {},
#  'VOICE': {},
#  'Meizu': {},
#  'OPhone': {},
#  'Calme': {},
#  'GRight': {},
#  "G'Five": {},
#  'Club': {}}

# %% [markdown]
# ##### For Samsung

# %%
driver.get(Brands["Samsung Mobile"])

for i in range(1, 110):

    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[4]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Samsung"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Galaxy Z Fold 2', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-2')
# ('Galaxy Z Flip', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Flip')
# ('Galaxy S20 Ultra', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20-Ultra')
# ('Galaxy Note 20 Ultra', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-20-Ultra')
# ('Galaxy S21 Ultra', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21-Ultra')
# ('Galaxy Note 10 Plus', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-10-Plus')
# 7
# ('Galaxy S20 Plus', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20-Plus')
# ('Galaxy S21 Plus', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21-Plus')
# ('Galaxy Note 20', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-20')
# ('Galaxy S20', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20')
# ('Galaxy Note 10', 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-10')
# ('Galaxy S21', 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21')
# 14
# 15
# 16
# ...

# %% [markdown]
# ##### For Alcatel

# %%
driver.get(Brands["Alcatel"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)

for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Idol 4s', 'https://www.whatmobile.com.pk/Alcatel_Idol-4s')
# ('Idol 4', 'https://www.whatmobile.com.pk/Alcatel_Idol-4')
# ('Idol 3', 'https://www.whatmobile.com.pk/Alcatel_Idol-3')
# ('X1', 'https://www.whatmobile.com.pk/Alcatel_X1')
# ('3X', 'https://www.whatmobile.com.pk/Alcatel_3X')
# ('1SE', 'https://www.whatmobile.com.pk/Alcatel_1SE')
# ('1S 2020', 'https://www.whatmobile.com.pk/Alcatel_1S-2020')
# ('Pop 4S', 'https://www.whatmobile.com.pk/Alcatel_Pop-4S')
# ('Tablet Pixi4 LTE', 'https://www.whatmobile.com.pk/Alcatel_Tablet-Pixi4-LTE')
# ('Pop Star 4G', 'https://www.whatmobile.com.pk/Alcatel_Pop-Star-4G')
# ('Pop 4', 'https://www.whatmobile.com.pk/Alcatel_Pop-4')
# ('Pop Up', 'https://www.whatmobile.com.pk/Alcatel_Pop-Up')
# ('Pixi 4 Power Plus', 'https://www.whatmobile.com.pk/Alcatel_Pixi-4-Power-Plus')
# ('Pop Star', 'https://www.whatmobile.com.pk/Alcatel_Pop-Star')
# ('Pixi 4 6', 'https://www.whatmobile.com.pk/Alcatel_Pixi-4-6')
# ...

# %% [markdown]
# ##### For Apple

# %%
driver.get(Brands["Apple iphone"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[8]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[10]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[17]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[19]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[21]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[23]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[25]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('iPhone 11 Pro Max', 'https://www.whatmobile.com.pk/Apple_iPhone-11-Pro-Max')
# ('iPhone 12 Pro Max', 'https://www.whatmobile.com.pk/Apple_iPhone-12-Pro-Max')
# ('iPhone 11 Pro', 'https://www.whatmobile.com.pk/Apple_iPhone-11-Pro')
# ('iPhone 12 Pro', 'https://www.whatmobile.com.pk/Apple_iPhone-12-Pro')
# ('iPhone XS Max', 'https://www.whatmobile.com.pk/Apple_iPhone-XS-Max')
# ('iPhone 12', 'https://www.whatmobile.com.pk/Apple_iPhone-12')
# ('iPhone 11', 'https://www.whatmobile.com.pk/Apple_iPhone-11')
# ('iPhone XR', 'https://www.whatmobile.com.pk/Apple_iPhone-XR')
# ('iPhone7 Plus 128GB', 'https://www.whatmobile.com.pk/Apple_iPhone7-Plus-128GB')
# ('iPhone X', 'https://www.whatmobile.com.pk/Apple_iPhone-X')
# ('iPhone XS', 'https://www.whatmobile.com.pk/Apple_iPhone-XS')
# ('iPhone 12 Mini', 'https://www.whatmobile.com.pk/Apple_iPhone-12-Mini')
# ('iphone 8 Plus', 'https://www.whatmobile.com.pk/Apple_iphone-8-Plus')
# ...

# %% [markdown]
# ##### For Calme

# %%
driver.get(Brands["Calme"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Calme"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Calme"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Spark S33', 'https://www.whatmobile.com.pk/Calme_Spark-S33')
# ('Spark S20', 'https://www.whatmobile.com.pk/Calme_Spark-S20')
# ('Spark S30', 'https://www.whatmobile.com.pk/Calme_Spark-S30')
# ('Spark S8', 'https://www.whatmobile.com.pk/Calme_Spark-S8')
# ('Spark S22', 'https://www.whatmobile.com.pk/Calme_Spark-S22')
# ('Spark S9', 'https://www.whatmobile.com.pk/Calme_Spark-S9')
# ('Spark S10', 'https://www.whatmobile.com.pk/Calme_Spark-S10')
# ('Spark S25', 'https://www.whatmobile.com.pk/Calme_Spark-S25')
# ('Spark S24', 'https://www.whatmobile.com.pk/Calme_Spark-S24')
# ('Spark S15', 'https://www.whatmobile.com.pk/Calme_Spark-S15')
# ('Spark S12', 'https://www.whatmobile.com.pk/Calme_Spark-S12')
# ('Spark S7', 'https://www.whatmobile.com.pk/Calme_Spark-S7')

# %% [markdown]
# ##### For GFive

# %%
driver.get(Brands["G'Five"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 3):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('President Tango 7', 'https://www.whatmobile.com.pk/GFive_President-Tango-7')
# ('President G10', 'https://www.whatmobile.com.pk/GFive_President-G10')
# ('G10 Honor', 'https://www.whatmobile.com.pk/GFive_G10-Honor')
# ('Glory A86', 'https://www.whatmobile.com.pk/GFive_Glory-A86')
# ('GPower 5', 'https://www.whatmobile.com.pk/GFive_GPower-5')
# ('4G LTE 3', 'https://www.whatmobile.com.pk/GFive_4G-LTE-3')
# ('President Xhero 7', 'https://www.whatmobile.com.pk/GFive_President-Xhero-7')
# ('President G6', 'https://www.whatmobile.com.pk/GFive_President-G6')
# ('President G10 Fashion', 'https://www.whatmobile.com.pk/GFive_President-G10-Fashion')
# ('President G9', 'https://www.whatmobile.com.pk/GFive_President-G9')
# ('Bravo G95', 'https://www.whatmobile.com.pk/GFive_Bravo-G95')
# ('GPower 3', 'https://www.whatmobile.com.pk/GFive_GPower-3')
# ('A79', 'https://www.whatmobile.com.pk/GFive_A79')
# ('President G10 Octa Core', 'https://www.whatmobile.com.pk/GFive_President-G10-Octa-Core')
# ...

# %% [markdown]
# ##### For HTC

# %%
driver.get(Brands["HTC"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[8]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[10]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[17]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[19]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[23]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[25]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[27]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# for i in range(1, 7):
#     try:
#         Phone = driver.find_element_by_xpath(
#             "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
#             + str(i)
#             + "]/h4/a"
#         )
#         PhoneName = str(Phone.text)
#         PhoneName = PhoneName.split("\n")
#         Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
#         print((PhoneName[1], Phone.get_attribute("href")))
#     except:
#         #         1 == 1
#         print(i)
# Out:
# ('U12 Plus', 'https://www.whatmobile.com.pk/HTC_U12-Plus')
# ('U11 Plus', 'https://www.whatmobile.com.pk/HTC_U11-Plus')
# ('U 11', 'https://www.whatmobile.com.pk/HTC_U-11')
# ('One A9', 'https://www.whatmobile.com.pk/HTC_One-A9')
# ('One M10', 'https://www.whatmobile.com.pk/HTC_One-M10')
# ('10', 'https://www.whatmobile.com.pk/HTC_10')
# ('One E8', 'https://www.whatmobile.com.pk/HTC_One-E8')
# ('One M9', 'https://www.whatmobile.com.pk/HTC_One-M9')
# ('U Ultra', 'https://www.whatmobile.com.pk/HTC_U-Ultra')
# ('One X9', 'https://www.whatmobile.com.pk/HTC_One-X9')
# ('Desire 610', 'https://www.whatmobile.com.pk/HTC_Desire-610')
# ('Desire 600', 'https://www.whatmobile.com.pk/HTC_Desire-600')
# ('One Mini', 'https://www.whatmobile.com.pk/HTC_One-Mini')
# ('One Mini 2', 'https://www.whatmobile.com.pk/HTC_One-Mini-2')
# ('Desire 626S', 'https://www.whatmobile.com.pk/HTC_Desire-626S')
# ('Desire 526G', 'https://www.whatmobile.com.pk/HTC_Desire-526G')
# ...

# %% [markdown]
# ##### For Huawei

# %%
driver.get(Brands["Huawei Mobile"])
for i in range(1, 58):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[3]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Huawei"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('P30 Pro', 'https://www.whatmobile.com.pk/Huawei_P30-Pro')
# ('Mate 20 Pro', 'https://www.whatmobile.com.pk/Huawei_Mate-20-Pro')
# ('P20 Pro', 'https://www.whatmobile.com.pk/Huawei_P20-Pro')
# ('P30', 'https://www.whatmobile.com.pk/Huawei_P30')
# ('Y9a', 'https://www.whatmobile.com.pk/Huawei_Y9a')
# ('Nova 7i', 'https://www.whatmobile.com.pk/Huawei_Nova-7i')
# 7
# ('Y9s 2019', 'https://www.whatmobile.com.pk/Huawei_Y9s-2019')
# ('P30 Lite', 'https://www.whatmobile.com.pk/Huawei_P30-Lite')
# ('Nova 3i', 'https://www.whatmobile.com.pk/Huawei_Nova-3i')
# ('Y7a', 'https://www.whatmobile.com.pk/Huawei_Y7a')
# ('Y9 Prime 2019', 'https://www.whatmobile.com.pk/Huawei_Y9-Prime-2019')
# ('Y8p', 'https://www.whatmobile.com.pk/Huawei_Y8p')
# 14
# 15
# 16
# ('Watch GT', 'https://www.whatmobile.com.pk/Huawei_Watch-GT')
# ('Y7p', 'https://www.whatmobile.com.pk/Huawei_Y7p')
# ('MediaPad T3 10', 'https://www.whatmobile.com.pk/Huawei_MediaPad-T3-10')
# ...

# %% [markdown]
# ##### For Infinix

# %%
driver.get(Brands["Infinix Mobile"])
for i in range(1, 78):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[4]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Infinix"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Zero 8', 'https://www.whatmobile.com.pk/Infinix_Zero-8')
# ('Zero 8i', 'https://www.whatmobile.com.pk/Infinix_Zero-8i')
# ('Note 10 Pro 256GB', 'https://www.whatmobile.com.pk/Infinix_Note-10-Pro-256GB')
# ('Note 10 Pro', 'https://www.whatmobile.com.pk/Infinix_Note-10-Pro')
# ('Note 8', 'https://www.whatmobile.com.pk/Infinix_Note-8')
# ('Note 7 6GB', 'https://www.whatmobile.com.pk/Infinix_Note-7-6GB')
# 7
# ('S5 Pro 6GB', 'https://www.whatmobile.com.pk/Infinix_S5-Pro-6GB')
# ('Note 8i', 'https://www.whatmobile.com.pk/Infinix_Note-8i')
# ('Note 7', 'https://www.whatmobile.com.pk/Infinix_Note-7')
# ('Hot 10 6GB', 'https://www.whatmobile.com.pk/Infinix_Hot-10-6GB')
# ('Note 7 Lite 6GB', 'https://www.whatmobile.com.pk/Infinix_Note-7-Lite-6GB')
# ('Hot 10S', 'https://www.whatmobile.com.pk/Infinix_Hot-10S')
# 14
# 15
# 16
# ('Note 7 64GB', 'https://www.whatmobile.com.pk/Infinix_Note-7-64GB')
# ('Note 7 Lite 128', 'https://www.whatmobile.com.pk/Infinix_Note-7-Lite-128')
# ...

# %% [markdown]
# ##### For LG

# %%
driver.get(Brands["LG Mobile"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[24]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[26]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Ray', 'https://www.whatmobile.com.pk/LG_Ray')
# ('G Vista 2', 'https://www.whatmobile.com.pk/LG_G-Vista-2')
# ('G Pro 2', 'https://www.whatmobile.com.pk/LG_G-Pro-2')
# ('V10', 'https://www.whatmobile.com.pk/LG_V10')
# ('X venture', 'https://www.whatmobile.com.pk/LG_X-venture')
# ('X Cam', 'https://www.whatmobile.com.pk/LG_X-Cam')
# ('Nexus 4', 'https://www.whatmobile.com.pk/LG_Nexus-4')
# ('Nexus 5', 'https://www.whatmobile.com.pk/LG_Nexus-5')
# ('Nexus 5X', 'https://www.whatmobile.com.pk/LG_Nexus-5X')
# ('G4', 'https://www.whatmobile.com.pk/LG_G4')
# ('V20', 'https://www.whatmobile.com.pk/LG_V20')
# ('W30 Pro', 'https://www.whatmobile.com.pk/LG_W30-Pro')
# ('Optimus 3D Max P720', 'https://www.whatmobile.com.pk/LG_Optimus-3D-Max-P720')
# ('Q6', 'https://www.whatmobile.com.pk/LG_Q6')
# ('Optimus Vu P895', 'https://www.whatmobile.com.pk/LG_Optimus-Vu-P895')
# ('Optimus 4X HD P880', 'https://www.whatmobile.com.pk/LG_Optimus-4X-HD-P880')
# ...

# %% [markdown]
# ##### For Lenovo

# %%
driver.get(Brands["Lenovo Mobile"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Moto Z', 'https://www.whatmobile.com.pk/Lenovo_Moto-Z')
# ('Vibe Z2', 'https://www.whatmobile.com.pk/Lenovo_Vibe-Z2')
# ('Vibe P2', 'https://www.whatmobile.com.pk/Lenovo_Vibe-P2')
# ('Vibe S1', 'https://www.whatmobile.com.pk/Lenovo_Vibe-S1')
# ('S5', 'https://www.whatmobile.com.pk/Lenovo_S5')
# ('Vibe P1', 'https://www.whatmobile.com.pk/Lenovo_Vibe-P1')
# ('K5 Note', 'https://www.whatmobile.com.pk/Lenovo_K5-Note')
# ('Vibe X2', 'https://www.whatmobile.com.pk/Lenovo_Vibe-X2')
# ('A7010', 'https://www.whatmobile.com.pk/Lenovo_A7010')
# ('S90', 'https://www.whatmobile.com.pk/Lenovo_S90')
# ('Vibe S1 Lite', 'https://www.whatmobile.com.pk/Lenovo_Vibe-S1-Lite')
# ('K6 Note', 'https://www.whatmobile.com.pk/Lenovo_K6-Note')
# ('Zuk Z1', 'https://www.whatmobile.com.pk/Lenovo_Zuk-Z1')
# ('S60', 'https://www.whatmobile.com.pk/Lenovo_S60')
# ('P70', 'https://www.whatmobile.com.pk/Lenovo_P70')
# ('S860', 'https://www.whatmobile.com.pk/Lenovo_S860')
# ...

# %% [markdown]
# ##### For Motorola

# %%
driver.get(Brands["Motorola"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Moto Z Play', 'https://www.whatmobile.com.pk/Motorola_Moto-Z-Play')
# ('Moto G6 Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-G6-Plus')
# ('Moto X Style', 'https://www.whatmobile.com.pk/Motorola_Moto-X-Style')
# ('Moto G6', 'https://www.whatmobile.com.pk/Motorola_Moto-G6')
# ('Moto One Macro', 'https://www.whatmobile.com.pk/Motorola_Moto-One-Macro')
# ('Moto G5S Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-G5S-Plus')
# ('Moto E5 Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-E5-Plus')
# ('Moto M', 'https://www.whatmobile.com.pk/Motorola_Moto-M')
# ('Moto E6', 'https://www.whatmobile.com.pk/Motorola_Moto-E6')
# ('Moto E5', 'https://www.whatmobile.com.pk/Motorola_Moto-E5')
# ('Moto E6 Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-E6-Plus')
# ('Moto E4 Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-E4-Plus')
# ('Moto E4', 'https://www.whatmobile.com.pk/Motorola_Moto-E4')
# ('Moto C Plus', 'https://www.whatmobile.com.pk/Motorola_Moto-C-Plus')
# ...

# %% [markdown]
# ##### For Nokia

# %%
driver.get(Brands["Nokia"])

for i in range(1, 100):

    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Nokia"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('8.3 5G', 'https://www.whatmobile.com.pk/Nokia_8.3-5G')
# ('X20', 'https://www.whatmobile.com.pk/Nokia_X20')
# ('X10', 'https://www.whatmobile.com.pk/Nokia_X10')
# ('7.2', 'https://www.whatmobile.com.pk/Nokia_7.2')
# ('8.1', 'https://www.whatmobile.com.pk/Nokia_8.1')
# ('8', 'https://www.whatmobile.com.pk/Nokia_8')
# 7
# ('7.1', 'https://www.whatmobile.com.pk/Nokia_7.1')
# ('5.4', 'https://www.whatmobile.com.pk/Nokia_5.4')
# ('6.2', 'https://www.whatmobile.com.pk/Nokia_6.2')
# ('7 Plus', 'https://www.whatmobile.com.pk/Nokia_7-Plus')
# ('5.3', 'https://www.whatmobile.com.pk/Nokia_5.3')
# ('6.1 Plus', 'https://www.whatmobile.com.pk/Nokia_6.1-Plus')
# 14
# 15
# 16
# ('G20 128GB', 'https://www.whatmobile.com.pk/Nokia_G20-128GB')
# ('6 2018', 'https://www.whatmobile.com.pk/Nokia_6-2018')
# ('3.4', 'https://www.whatmobile.com.pk/Nokia_3.4')
# ('G20', 'https://www.whatmobile.com.pk/Nokia_G20')
# ('5.1 Plus', 'https://www.whatmobile.com.pk/Nokia_5.1-Plus')
# ...

# %% [markdown]
# ##### For OnePlus

# %%
driver.get(Brands["OnePlus"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('8 Pro 12GB', 'https://www.whatmobile.com.pk/OnePlus_8-Pro-12GB')
# ('8 Pro', 'https://www.whatmobile.com.pk/OnePlus_8-Pro')
# ('8T 12GB', 'https://www.whatmobile.com.pk/OnePlus_8T-12GB')
# ('8 12GB', 'https://www.whatmobile.com.pk/OnePlus_8-12GB')
# ('8', 'https://www.whatmobile.com.pk/OnePlus_8')
# ('8T', 'https://www.whatmobile.com.pk/OnePlus_8T')
# ('Nord 12GB', 'https://www.whatmobile.com.pk/OnePlus_Nord-12GB')
# ('7 Pro', 'https://www.whatmobile.com.pk/OnePlus_7-Pro')
# ('7T Pro', 'https://www.whatmobile.com.pk/OnePlus_7T-Pro')
# ('7T', 'https://www.whatmobile.com.pk/OnePlus_7T')
# ('Nord', 'https://www.whatmobile.com.pk/OnePlus_Nord')
# ('7', 'https://www.whatmobile.com.pk/OnePlus_7')
# ('Nord N10', 'https://www.whatmobile.com.pk/OnePlus_Nord-N10')
# ('Nord N100', 'https://www.whatmobile.com.pk/OnePlus_Nord-N100')
# ('5', 'https://www.whatmobile.com.pk/OnePlus_5')
# ('5T', 'https://www.whatmobile.com.pk/OnePlus_5T')
# ('6', 'https://www.whatmobile.com.pk/OnePlus_6')
# ...

# %% [markdown]
# #### For Oppo

# %%
driver.get(Brands["OPPO Mobile"])
for i in range(1, 65):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OPPO"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Reno 5 Pro', 'https://www.whatmobile.com.pk/Oppo_Reno-5-Pro')
# ('Reno 4 Pro', 'https://www.whatmobile.com.pk/Oppo_Reno-4-Pro')
# ('Reno 4', 'https://www.whatmobile.com.pk/Oppo_Reno-4')
# ('Reno 3 Pro', 'https://www.whatmobile.com.pk/Oppo_Reno-3-Pro')
# ('Reno 5', 'https://www.whatmobile.com.pk/Oppo_Reno-5')
# ('F19 Pro', 'https://www.whatmobile.com.pk/Oppo_F19-Pro')
# 7
# ('Reno 3', 'https://www.whatmobile.com.pk/Oppo_Reno-3')
# ('Reno 2F', 'https://www.whatmobile.com.pk/Oppo_Reno-2F')
# ('F17 Pro', 'https://www.whatmobile.com.pk/Oppo_F17-Pro')
# ('F19', 'https://www.whatmobile.com.pk/Oppo_F19')
# ('F17', 'https://www.whatmobile.com.pk/Oppo_F17')
# ('A9 2020', 'https://www.whatmobile.com.pk/Oppo_A9-2020')
# 14
# 15
# 16
# ('A52', 'https://www.whatmobile.com.pk/Oppo_A52')
# ('A54', 'https://www.whatmobile.com.pk/Oppo_A54')
# ('A5 2020', 'https://www.whatmobile.com.pk/Oppo_A5-2020')
# ('A7', 'https://www.whatmobile.com.pk/Oppo_A7')
# ...

# %% [markdown]
# #### For Qmobile

# %%
driver.get(Brands["QMobile"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[2]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[4]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[11]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[13]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[15]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[17]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[19]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[21]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[23]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[25]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[27]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[29]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[31]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[33]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[35]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[35]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[37]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[39]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[41]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[43]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Noir E8', 'https://www.whatmobile.com.pk/Qmobile_Noir-E8')
# ('Noir Z14', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z14')
# ('Noir A1', 'https://www.whatmobile.com.pk/Qmobile_Noir-A1')
# ('Noir Z12', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z12')
# ('Noir M6', 'https://www.whatmobile.com.pk/Qmobile_Noir-M6')
# ('Noir Z9 Plus', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z9-Plus')
# ('Noir Z9', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z9')
# ('Phantom P1 Pro', 'https://www.whatmobile.com.pk/Qmobile_Phantom-P1-Pro')
# ('QInfinity Prime', 'https://www.whatmobile.com.pk/Qmobile_QInfinity-Prime')
# ('Noir Z8 Plus', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z8-Plus')
# ('Noir Z12 Pro', 'https://www.whatmobile.com.pk/Qmobile_Noir-Z12-Pro')
# ('Noir A1 Lite', 'https://www.whatmobile.com.pk/Qmobile_Noir-A1-Lite')
# ('Phantom P1', 'https://www.whatmobile.com.pk/Qmobile_Phantom-P1')
# ('Q Infinity', 'https://www.whatmobile.com.pk/Qmobile_Q-Infinity')
# ...

# %% [markdown]
# #### For Realme

# %%
driver.get(Brands["Realme Mobile"])
for i in range(1, 44):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Realme"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('X3 Super Zoom', 'https://www.whatmobile.com.pk/Realme_X3-Super-Zoom')
# ('7 Pro', 'https://www.whatmobile.com.pk/Realme_7-Pro')
# ('6 pro', 'https://www.whatmobile.com.pk/Realme_6-pro')
# ('XT', 'https://www.whatmobile.com.pk/Realme_XT')
# ('8 pro', 'https://www.whatmobile.com.pk/Realme_8-pro')
# ('2 Pro', 'https://www.whatmobile.com.pk/Realme_2-Pro')
# 7
# ('6 8GB', 'https://www.whatmobile.com.pk/Realme_6-8GB')
# ('5 Pro 8GB', 'https://www.whatmobile.com.pk/Realme_5-Pro-8GB')
# ('8', 'https://www.whatmobile.com.pk/Realme_8')
# ('3 Pro 6GB', 'https://www.whatmobile.com.pk/Realme_3-Pro-6GB')
# ('6', 'https://www.whatmobile.com.pk/Realme_6')
# ('3 Pro', 'https://www.whatmobile.com.pk/Realme_3-Pro')
# 14
# 15
# 16
# ('7i', 'https://www.whatmobile.com.pk/Realme_7i')
# ('5 Pro', 'https://www.whatmobile.com.pk/Realme_5-Pro')
# ('6i', 'https://www.whatmobile.com.pk/Realme_6i')
# ('5s', 'https://www.whatmobile.com.pk/Realme_5s')
# ('C17', 'https://www.whatmobile.com.pk/Realme_C17')
# ...

# %% [markdown]
# #### For Sony

# %%
driver.get(Brands["Sony"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[24]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Xperia X Premium', 'https://www.whatmobile.com.pk/Sony_Xperia-X-Premium')
# ('Xperia XZ Premium', 'https://www.whatmobile.com.pk/Sony_Xperia-XZ-Premium')
# ('Xperia XZ1', 'https://www.whatmobile.com.pk/Sony_Xperia-XZ1')
# ('Xperia XZs', 'https://www.whatmobile.com.pk/Sony_Xperia-XZs')
# ('Xperia X Performance', 'https://www.whatmobile.com.pk/Sony_Xperia-X-Performance')
# ('Xperia XA2 Ultra', 'https://www.whatmobile.com.pk/Sony_Xperia-XA2-Ultra')
# ('Xperia X Compact', 'https://www.whatmobile.com.pk/Sony_Xperia-X-Compact')
# ('Xperia Z5 Premium', 'https://www.whatmobile.com.pk/Sony_Xperia-Z5-Premium')
# ('Xperia XZ', 'https://www.whatmobile.com.pk/Sony_Xperia-XZ')
# ('Xperia Z5 Compact', 'https://www.whatmobile.com.pk/Sony_Xperia-Z5-Compact')
# ('Xperia Z5', 'https://www.whatmobile.com.pk/Sony_Xperia-Z5')
# ('Xperia XA1 Ultra', 'https://www.whatmobile.com.pk/Sony_Xperia-XA1-Ultra')
# ('Xperia X', 'https://www.whatmobile.com.pk/Sony_Xperia-X')
# ...

# %% [markdown]
# #### For Tecno

# %%
driver.get(Brands["Tecno Mobile"])
for i in range(1, 53):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Tecno"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Camon 16 Premier', 'https://www.whatmobile.com.pk/Tecno_Camon-16-Premier')
# ('Camon 16', 'https://www.whatmobile.com.pk/Tecno_Camon-16')
# ('Camon 17 Pro', 'https://www.whatmobile.com.pk/Tecno_Camon-17-Pro')
# ('Camon 16 Pro', 'https://www.whatmobile.com.pk/Tecno_Camon-16-Pro')
# ('Camon 15 Pro', 'https://www.whatmobile.com.pk/Tecno_Camon-15-Pro')
# ('Camon 16 SE', 'https://www.whatmobile.com.pk/Tecno_Camon-16-SE')
# 7
# ('Camon 17', 'https://www.whatmobile.com.pk/Tecno_Camon-17')
# ('Pova', 'https://www.whatmobile.com.pk/Tecno_Pova')
# ('Spark 7 Pro', 'https://www.whatmobile.com.pk/Tecno_Spark-7-Pro')
# ('Pouvoir 4 Pro', 'https://www.whatmobile.com.pk/Tecno_Pouvoir-4-Pro')
# ('Spark 5 Pro 128GB', 'https://www.whatmobile.com.pk/Tecno_Spark-5-Pro-128GB')
# ('Camon 15', 'https://www.whatmobile.com.pk/Tecno_Camon-15')
# 14
# 15
# 16
# ('Spark 6', 'https://www.whatmobile.com.pk/Tecno_Spark-6')
# ('Spark 7', 'https://www.whatmobile.com.pk/Tecno_Spark-7')
# ...

# %% [markdown]
# #### For Telenor

# %%
driver.get(Brands["Telenor"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Telenor"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
for i in range(1, 2):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[12]/td/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Telenor"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Infinity A', 'https://www.whatmobile.com.pk/Telenor_Infinity-A')
# ('Infinity E2', 'https://www.whatmobile.com.pk/Telenor_Infinity-E2')
# ('Infinity E3', 'https://www.whatmobile.com.pk/Telenor_Infinity-E3')
# ('Infinity E', 'https://www.whatmobile.com.pk/Telenor_Infinity-E')
# ('Infinity A2', 'https://www.whatmobile.com.pk/Telenor_Infinity-A2')
# ('Infinity i5', 'https://www.whatmobile.com.pk/Telenor_Infinity-i5')
# ('Infinity I', 'https://www.whatmobile.com.pk/Telenor_Infinity-I')

# %% [markdown]
# #### For Vivo

# %%
driver.get(Brands["Vivo"])
for i in range(1, 43):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Vivo"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('X60 Pro', 'https://www.whatmobile.com.pk/Vivo_X60-Pro')
# ('V21', 'https://www.whatmobile.com.pk/Vivo_V21')
# ('V20', 'https://www.whatmobile.com.pk/Vivo_V20')
# ('V20 SE', 'https://www.whatmobile.com.pk/Vivo_V20-SE')
# ('S1 Pro', 'https://www.whatmobile.com.pk/Vivo_S1-Pro')
# ('Y51s', 'https://www.whatmobile.com.pk/Vivo_Y51s')
# 7
# ('S1 4GB', 'https://www.whatmobile.com.pk/Vivo_S1-4GB')
# ('S1', 'https://www.whatmobile.com.pk/Vivo_S1')
# ('Y31', 'https://www.whatmobile.com.pk/Vivo_Y31')
# ('Y17', 'https://www.whatmobile.com.pk/Vivo_Y17')
# ('Y51', 'https://www.whatmobile.com.pk/Vivo_Y51')
# ('Y20s', 'https://www.whatmobile.com.pk/Vivo_Y20s')
# 14
# 15
# 16
# ('Y30 128GB', 'https://www.whatmobile.com.pk/Vivo_Y30-128GB')
# ('Y30', 'https://www.whatmobile.com.pk/Vivo_Y30')
# ('Y20', 'https://www.whatmobile.com.pk/Vivo_Y20')
# ('Y12', 'https://www.whatmobile.com.pk/Vivo_Y12')
# ('Y12s', 'https://www.whatmobile.com.pk/Vivo_Y12s')
# ('Y11', 'https://www.whatmobile.com.pk/Vivo_Y11')
# ...

# %% [markdown]
# #### For Xiaomi

# %%
# //*[@id="container"]/div[2]/div/div[2]/div[2]/div[6]/div/h4/a
# //*[@id="container"]/div[2]/div/div[2]/div[2]/div[66]/div/h4/a

driver.get(Brands["Xiaomi Mobile"])
for i in range(1, 67):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Xiaomi"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Mi 10', 'https://www.whatmobile.com.pk/Xiaomi_Mi-10')
# ('Mi 11', 'https://www.whatmobile.com.pk/Xiaomi_Mi-11')
# ('Pocophone F2 Pro', 'https://www.whatmobile.com.pk/Xiaomi_Pocophone-F2-Pro')
# ('Mi Note 10 Pro', 'https://www.whatmobile.com.pk/Xiaomi_Mi-Note-10-Pro')
# ('Mi Note 10', 'https://www.whatmobile.com.pk/Xiaomi_Mi-Note-10')
# ('Poco F3 8GB', 'https://www.whatmobile.com.pk/Xiaomi_Poco-F3-8GB')
# 7
# ('Mi 10T', 'https://www.whatmobile.com.pk/Xiaomi_Mi-10T')
# ('Mi Note 10 Lite', 'https://www.whatmobile.com.pk/Xiaomi_Mi-Note-10-Lite')
# ('Mi 10T 6GB', 'https://www.whatmobile.com.pk/Xiaomi_Mi-10T-6GB')
# ('Poco F3', 'https://www.whatmobile.com.pk/Xiaomi_Poco-F3')
# ('Mi 10T Lite', 'https://www.whatmobile.com.pk/Xiaomi_Mi-10T-Lite')
# ('Redmi Note 10 Pro 8GB', 'https://www.whatmobile.com.pk/Xiaomi_Redmi-Note-10-Pro-8GB')
# 14
# 15
# 16
# ('Poco X3 Pro 8GB', 'https://www.whatmobile.com.pk/Xiaomi_Poco-X3-Pro-8GB')
# ...

# %% [markdown]
# #### For itel

# %%
driver.get(Brands["itel"])
for i in range(1, 13):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["itel"][PhoneName[1]] = Phone.get_attribute("href")
        print((PhoneName[1], Phone.get_attribute("href")))
    except:
        #         1 == 1
        print(i)
# Out:
# ('Vision 2', 'https://www.whatmobile.com.pk/itel_Vision-2')
# ('Vision 1 Pro 3GB', 'https://www.whatmobile.com.pk/itel_Vision-1-Pro-3GB')
# ('Vision 1 Plus', 'https://www.whatmobile.com.pk/itel_Vision-1-Plus')
# ('Vision 1 Pro', 'https://www.whatmobile.com.pk/itel_Vision-1-Pro')
# ('A48', 'https://www.whatmobile.com.pk/itel_A48')
# ('Vision 1', 'https://www.whatmobile.com.pk/itel_Vision-1')
# 7
# ('A25 Pro', 'https://www.whatmobile.com.pk/itel_A25-Pro')
# ('A25', 'https://www.whatmobile.com.pk/itel_A25')
# ('A36', 'https://www.whatmobile.com.pk/itel_A36')
# ('A23 Pro', 'https://www.whatmobile.com.pk/itel_A23-Pro')
# ('A14 Max', 'https://www.whatmobile.com.pk/itel_A14-Max')

# %%
Phones
# Out:
# {'Samsung': {},
#  'Huawei': {'P30 Pro': 'https://www.whatmobile.com.pk/Huawei_P30-Pro',
#   'Mate 20 Pro': 'https://www.whatmobile.com.pk/Huawei_Mate-20-Pro',
#   'P20 Pro': 'https://www.whatmobile.com.pk/Huawei_P20-Pro',
#   'P30': 'https://www.whatmobile.com.pk/Huawei_P30',
#   'Y9a': 'https://www.whatmobile.com.pk/Huawei_Y9a',
#   'Nova 7i': 'https://www.whatmobile.com.pk/Huawei_Nova-7i',
#   'Y9s 2019': 'https://www.whatmobile.com.pk/Huawei_Y9s-2019',
#   'P30 Lite': 'https://www.whatmobile.com.pk/Huawei_P30-Lite',
#   'Nova 3i': 'https://www.whatmobile.com.pk/Huawei_Nova-3i',
#   'Y7a': 'https://www.whatmobile.com.pk/Huawei_Y7a',
#   'Y9 Prime 2019': 'https://www.whatmobile.com.pk/Huawei_Y9-Prime-2019',
#   'Y8p': 'https://www.whatmobile.com.pk/Huawei_Y8p',
#   'Watch GT': 'https://www.whatmobile.com.pk/Huawei_Watch-GT',
#   'Y7p': 'https://www.whatmobile.com.pk/Huawei_Y7p',
#   'MediaPad T3 10': 'https://www.whatmobile.com.pk/Huawei_MediaPad-T3-10',
# ...

# %%
Phones
# Out:
# {'Samsung': {},
#  'Huawei': {'P30 Pro': 'https://www.whatmobile.com.pk/Huawei_P30-Pro',
#   'Mate 20 Pro': 'https://www.whatmobile.com.pk/Huawei_Mate-20-Pro',
#   'P20 Pro': 'https://www.whatmobile.com.pk/Huawei_P20-Pro',
#   'P30': 'https://www.whatmobile.com.pk/Huawei_P30',
#   'Y9a': 'https://www.whatmobile.com.pk/Huawei_Y9a',
#   'Nova 7i': 'https://www.whatmobile.com.pk/Huawei_Nova-7i',
#   'Y9s 2019': 'https://www.whatmobile.com.pk/Huawei_Y9s-2019',
#   'P30 Lite': 'https://www.whatmobile.com.pk/Huawei_P30-Lite',
#   'Nova 3i': 'https://www.whatmobile.com.pk/Huawei_Nova-3i',
#   'Y7a': 'https://www.whatmobile.com.pk/Huawei_Y7a',
#   'Y9 Prime 2019': 'https://www.whatmobile.com.pk/Huawei_Y9-Prime-2019',
#   'Y8p': 'https://www.whatmobile.com.pk/Huawei_Y8p',
#   'Watch GT': 'https://www.whatmobile.com.pk/Huawei_Watch-GT',
#   'Y7p': 'https://www.whatmobile.com.pk/Huawei_Y7p',
#   'MediaPad T3 10': 'https://www.whatmobile.com.pk/Huawei_MediaPad-T3-10',
# ...

# %%
# for j in range(len(Phones)):

# df = pd.read_html(Phones['Apple']['iphone 6'].get_attribute("href"))
#     new = df[0]
# new.insert(0, "Phone", Phones[0].text, True)
# new.set_index(["Phone", 0, 1], inplace=True)
df = pd.read_html(Phones["Huawei"]["Mate 20 Pro"])

df[0].drop(columns=[3], inplace=True)
#     DataFrames.append(new)
# print(df)
df[0]
# Phones.clear()
# Out:
#                0               1  \
# 0          Build              OS
# 1          Build              UI
# 2          Build      Dimensions
# 3          Build          Weight
# 4          Build             SIM
# 5          Build          Colors
# 6      Frequency         2G Band
# 7      Frequency         3G Band
# 8      Frequency         4G Band
# 9      Processor             CPU
# 10     Processor         Chipset
# 11     Processor             GPU
# 12       Display      Technology
# 13       Display            Size
# 14       Display      Resolution
# 15       Display      Protection
# 16       Display  Extra Features
# 17        Memory        Built-in
# 18        Memory            Card
# 19        Camera            Main
# 20        Camera        Features
# 21        Camera           Front
# 22  Connectivity            WLAN
# 23  Connectivity       Bluetooth
# 24  Connectivity             GPS
# 25  Connectivity           Radio
# 26  Connectivity             USB
# ...

# %%
# type(df[0])
SpecList = list()
Build = df[0].loc[df[0][0] == "Build"]
Frequency = df[0].loc[df[0][0] == "Frequency"]
Processor = df[0].loc[df[0][0] == "Processor"]
Display = df[0].loc[df[0][0] == "Display"]
Memory = df[0].loc[df[0][0] == "Memory"]
Camera = df[0].loc[df[0][0] == "Camera"]
Connectivity = df[0].loc[df[0][0] == "Connectivity"]
Features = df[0].loc[df[0][0] == "Frequency"]
Battery = df[0].loc[df[0][0] == "Battery"]
SubDict = dict()

for i in range(0, Build.shape[0]):
    SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]
Set = ("Build", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Frequency.shape[0]):
    SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
Set = ("Frequency", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Processor.shape[0]):
    SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
Set = ("Processor", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Display.shape[0]):
    SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
Set = ("Display", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Memory.shape[0]):
    SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
Set = ("Memory", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Camera.shape[0]):
    SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
Set = ("Camera", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Connectivity.shape[0]):
    SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
Set = ("Connectivity", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Features.shape[0]):
    SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
Set = ("Features", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Battery.shape[0]):
    SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
Set = ("Battery", SubDict)
SpecList.append(Set)

# %%
# SubDict
SpecList
# type(Set)
# Out:
# [('Build',
#   {'OS': 'Android 9.0 (Pie)',
#    'UI': 'EMUI 9.0',
#    'Dimensions': '157.8 x 72.3 x 8.6 mm',
#    'Weight': '189 g',
#    'SIM': 'Dual Sim, Dual Standby (Nano-SIM)',
#    'Colors': 'Emerald Green, Midnight Blue, Twilight, Pink Gold, Black'}),
#  ('Frequency',
#   {'2G Band': 'SIM1: GSM 850 / 900 / 1800 / 1900SIM2: GSM 850 / 900 / 1800 / 1900',
#    '3G Band': 'HSDPA 850 / 900 / 1900 / 2100',
#    '4G Band': 'LTE band 1(2100), 2(1900), 3(1800), 4(1700/2100), 5(850), 6(900), 7(2600), 8(900), 9(1800), 12(700), 17(700), 18(800), 19(800), 20(800), 26(850), 28(700), 32(1500), 34(2000), 38(2600), 39(1900), 40(2300)'}),
#  ('Processor',
#   {'CPU': 'Octa-core (2 x 2.6 GHz Cortex-A76 + 2 x 1.92 GHz Cortex-A76 + 4 x 1.8 GHz Cortex-A55)',
#    'Chipset': 'HiSilicon Kirin 980 (7 nm)',
#    'GPU': 'Mali-G76 MP10'}),
#  ('Display',
#   {'Technology': 'AMOLED Capacitive Touchscreen, 16M Colors, Multitouch',
#    'Size': '6.4 Inches',
# ...

# %%
collection = db.collection("Specifications")

# %%
for item in SpecList:
    try:
        collection.document(item[0]).set(item[1])
    except:
        print(item[1])

# %%
for key in SubDict:
    print(type(key))
# Out:
# <class 'str'>
# <class 'str'>

# %%
# Build.iloc[[1]]
# SubDict=dict()
for i in range(len(Build)):
    for j in range(0, 2):
        #         print(Build.iloc[[i]][[j]])
        a = Build.iloc[[i]][[j]]
        print(a)
# Out:
#        0
# 0  Build
#     1
# 0  OS
#        0
# 1  Build
#     1
# 1  UI
#        0
# 2  Build
#             1
# 2  Dimensions
#        0
# 3  Build
#         1
# 3  Weight
#        0
# 4  Build
#      1
# 4  SIM
#        0
# 5  Build
#         1
# 5  Colors

# %%
a[[1]]
# Out:
#         1
# 5  Colors
