# %%
import re
import time

import bs4 as bs
import firebase_admin
import pandas as pd
from firebase_admin import credentials, firestore
from selenium import webdriver

# %% [markdown]
# #### Firebase Credentials

# %%
# cred = credentials.Certificate(
#     "C://Users/OwaisGondal/Documents/Python/FYP/TestKey.json"
# )
cred = credentials.Certificate(
    "C://Users/OwaisGondal/Documents/Python/FYP/serviceAccountKey.json"
)

firebase_admin.initialize_app(cred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5d44d1530f8f> in <module>
#       6 )
#       7
# ----> 8 firebase_admin.initialize_app(cred)
#
# ~\Anaconda3\lib\site-packages\firebase_admin\__init__.py in initialize_app(credential, options, name)
#      69
#      70     if name == _DEFAULT_APP_NAME:
# ---> 71         raise ValueError((
#      72             'The default Firebase app already exists. This means you called '
#      73             'initialize_app() more than once without providing an app name as '
#
# ValueError: The default Firebase app already exists. This means you called initialize_app() more than once without providing an app name as the second argument. In most cases you only need to call initialize_app() once. But if you do want to initialize multiple apps, pass a second argument to initialize_app() to give each app a unique name.

# %% [markdown]
# #### Connect to Firebase

# %%
db = firestore.client()  # this connects to Firestore

# %% [markdown]
# #### Chrome Webdriver

# %%
# url = "https://www.whatmobile.com.pk/"
driver = webdriver.Chrome(
    "C:/Users/OwaisGondal/Downloads/Compressed/chromedriver_win32/chromedriver.exe"
)
# driver.get(url)

# %%
Names = []
Prices = []
Links = []
Vendors = []
V = [
    "Daraz",
    "Telemart",
    "Zaibis",
    "Myshop",
    "Symbios.pk",
    "Homeshopping",
    "Paklap",
    "Czone",
]

# %% [markdown]
# ### Myshop

# %%
url = "https://myshop.pk/mobiles-smartphones-tablets/smartphones?a_product_type=969&product_list_limit=64&product_list_order=name"

driver.get(url)
for i in range(1, 64):
    try:
        Name = driver.find_element_by_xpath(
            "/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li["
            + str(i)
            + "]/div/div[2]/strong/a"
        )
        Price = driver.find_element_by_xpath(
            "/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li["
            + str(i)
            + "]/div/div[2]/div[4]/span/span/span[2]/span"
        )
        Names.append(Name.text)
        Prices.append(Price.text)
        Links.append(Name.get_attribute("href"))
        Vendors.append(V[3])
    except:
        1 == 1

# %% [markdown]
# ### Zaibis

# %%
url = "https://www.zaibis.com/product-category/new-mobile-phones/"

driver.get(url)
for j in range(1, 12):
    driver.get(
        "https://www.zaibis.com/product-category/new-mobile-phones/page/" + str(j) + "/"
    )
    for i in range(1, 32):
        #         Name = driver.find_element_by_xpath(
        #             "/html/body/div[2]/div/div[3]/div/div/div[1]/main/ul/li["
        #             + str(i)
        #             + "]/div/div/div[1]/a/h2"

        #         )
        try:
            Name = driver.find_element_by_xpath(
                '//*[@id="main"]/ul/li[' + str(i) + "]/div/div/div[1]/a"
            )
            Price = driver.find_element_by_xpath(
                '//*[@id="main"]/ul/li[' + str(i) + "]/div/div/div[3]/div[1]/span"
            )
            Names.append(Name.text)
            Prices.append(Price.text)
            Vendors.append(V[2])
            if Name.get_attribute("href") != "None":
                Links.append(Name.get_attribute("href"))
        except:
            1 == 1

# %% [markdown]
# ### Symbios

# %%
url = "https://www.symbios.pk/smart-phones"

driver.get(url)
for i in range(1, 119):
    try:
        Name = driver.find_element_by_xpath(
            "/html/body/div[4]/div/div/div[2]/div[4]/div/div/div/div/div[1]/div["
            + str(i)
            + "]/div/div/div[2]/h3/a"
        )
        Price = driver.find_element_by_xpath(
            "/html/body/div[4]/div/div/div[2]/div[4]/div/div/div/div/div[1]/div["
            + str(i)
            + "]/div/div/div[2]/div[3]/span[1]"
        )
        Names.append(Name.text)
        Prices.append(Price.text)
        Vendors.append(V[4])
        Links.append(Name.get_attribute("href"))
    except:
        1 == 1

# %% [markdown]
# ### HomeShopping

# %%
url = "https://homeshopping.pk/categories/Mobile-Phones-Price-Pakistan"
# driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
for j in range(1, 21):
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight-1200)")
    time.sleep(3)
    for i in range(1, 25):
        try:
            Name = driver.find_element_by_xpath(
                "/html/body/div[1]/div[9]/div[2]/div[2]/div[5]/div/div["
                + str(i * j)
                + "]/div/h5/a"
            )
            Price = driver.find_element_by_xpath(
                "/html/body/div[1]/div[9]/div[2]/div[2]/div[5]/div/div["
                + str(i * j)
                + "]/div/div[2]/a/div"
            )
            Names.append(Name.text)
            Prices.append(Price.text)
            Vendors.append(V[5])
            Links.append(Name.get_attribute("href"))
        except:
            1 == 1

# %% [markdown]
# ### Daraz

# %%
for i in range(81):
    driver.get("https://www.daraz.pk/smartphones/?page=" + str(i))
    try:
        for j in range(1, 40):
            Name = driver.find_element_by_xpath(
                '//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['
                + str(j)
                + "]/div/div/div[2]/div[2]/a"
            )
            Price = driver.find_element_by_xpath(
                '//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['
                + str(j)
                + "]/div/div/div[2]/div[3]/span"
            )
            #             Image = driver.find_elements_by_xpath(
            #                 '//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['
            #                 + str(j)
            #                 + "]/div/div/div[1]/div[1]/a/img"
            #             )
            Names.append(Name.text)
            Vendors.append(V[0])
            #             Images.append(Image.get_attribute("src"))
            Prices.append(Price.text)
            Links.append(Name.get_attribute("href"))
    except:
        1 == 1

# %%
df = pd.DataFrame(
    list(zip(Names, Prices, Vendors, Links)),
    columns=["Name", "Price", "Vendor", "VendorLink"],
)
# df.sort_values(["Name", "Price"], inplace=True)
# df.reset_index(0, inplace=True)
df
# Out:
#                                                    Name       Price  Vendor  \
# 0             Apple | iPhone 11 - 128 GB Single Sim :1Y  Rs 149,900  Myshop
# 1         Apple | iPhone 11 Pro - 512 GB Single Sim :1Y  Rs 214,900  Myshop
# 2     Apple | iPhone 11 Pro Max - 512 GB Single Sim :1Y  Rs 234,900  Myshop
# 3                          Huawei Nova 7i - (128GB) :1Y   Rs 41,999  Myshop
# 4                               Huawei Y6P - (64GB) :1Y   Rs 20,900  Myshop
# ...                                                 ...         ...     ...
# 3811                                           L-3 Plus   Rs. 1,550   Daraz
# 3812  Nokia 5.4 smartphone with a 6.39" HD+ screen, ...  Rs. 31,999   Daraz
# 3813         Redmi 9T 4GB Ram 128GB Rom 6000mAh Battery  Rs. 27,999   Daraz
# 3814  Samsung Galaxy A30S - 6.4 Display - Main Camer...  Rs. 38,999   Daraz
# 3815  REDMI NOTE 10 4GB RAM 128GB ROM Super AMOLED D...  Rs. 31,250   Daraz
#
#                                              VendorLink
# ...

# %% [markdown]
# #### Scraping

# %%
driver.get("https://www.whatmobile.com.pk/")
BrandKeys = []
BrandValues = []
for i in range(1, 35):
    BrandKeys.append(
        driver.find_element_by_xpath(
            '//*[@id="container"]/div[3]/div/div[2]/section[2]/ul/li[' + str(i) + "]/a"
        ).text
    )
    BrandValues.append(
        driver.find_element_by_xpath(
            '//*[@id="container"]/div[3]/div/div[2]/section[2]/ul/li[' + str(i) + "]/a"
        ).get_attribute("href")
    )

# %%
Brands = dict(zip(BrandKeys, BrandValues))
Phones = dict()
Phone = None

for key in Brands:
    Phones[key.split(" ")[0]] = {}
# Phones
# Brands

# %% [markdown]
# ##### For Samsung

# %%
driver.get(Brands["Samsung Mobile"])

for i in range(1, 110):

    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[4]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Samsung"][PhoneName[1]] = Phone.get_attribute("href")
    #         #print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
#         #print(i)

# %% [markdown]
# ##### For Alcatel

# %%
driver.get(Brands["Alcatel"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
    #         #print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
#         #print(i)

for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
        ##print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Alcatel"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Apple

# %%
driver.get(Brands["Apple iphone"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[8]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[10]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[17]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[19]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[21]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[23]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[25]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Apple"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Calme

# %%
driver.get(Brands["Calme"])
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Calme"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):

    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Calme"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For GFive

# %%
driver.get(Brands["G'Five"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 3):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["G'Five"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For HTC

# %%
driver.get(Brands["HTC"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[8]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[10]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[17]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[19]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[23]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[25]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[27]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["HTC"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Huawei

# %%
driver.get(Brands["Huawei Mobile"])
for i in range(1, 58):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[3]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Huawei"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Infinix

# %%
driver.get(Brands["Infinix Mobile"])
for i in range(1, 78):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[4]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Infinix"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For LG

# %%
driver.get(Brands["LG Mobile"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[24]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[26]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["LG"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Lenovo

# %%
driver.get(Brands["Lenovo Mobile"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Lenovo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Motorola

# %%
driver.get(Brands["Motorola"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 6):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Motorola"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For Nokia

# %%
driver.get(Brands["Nokia"])

for i in range(1, 100):

    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Nokia"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# ##### For OnePlus

# %%
driver.get(Brands["OnePlus"])

for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OnePlus"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Oppo

# %%
driver.get(Brands["OPPO Mobile"])
for i in range(1, 65):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["OPPO"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Qmobile

# %%
driver.get(Brands["QMobile"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[2]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[4]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[11]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[13]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[15]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[17]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[19]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[21]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[23]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[25]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[27]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[29]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[31]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[33]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[35]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[35]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[37]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[39]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[41]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/table/tbody/tr[43]/td['
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["QMobile"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Realme

# %%
driver.get(Brands["Realme Mobile"])
for i in range(1, 44):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Realme"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Sony

# %%
driver.get(Brands["Sony"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[7]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[14]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[16]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[18]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[20]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[22]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[24]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Sony"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Tecno

# %%
driver.get(Brands["Tecno Mobile"])
for i in range(1, 53):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Tecno"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Telenor

# %%
driver.get(Brands["Telenor"])
for i in range(1, 7):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[5]/td["
            + str(i)
            + "]/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Telenor"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)
for i in range(1, 2):
    try:
        Phone = driver.find_element_by_xpath(
            "/html/body/table/tbody/tr[2]/td[2]/table/tbody/tr[12]/td/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Telenor"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Vivo

# %%
driver.get(Brands["Vivo"])
for i in range(1, 43):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Vivo"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For Xiaomi

# %%
# //*[@id="container"]/div[2]/div/div[2]/div[2]/div[6]/div/h4/a
# //*[@id="container"]/div[2]/div/div[2]/div[2]/div[66]/div/h4/a

driver.get(Brands["Xiaomi Mobile"])
for i in range(1, 67):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["Xiaomi"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %% [markdown]
# #### For itel

# %%
driver.get(Brands["itel"])
for i in range(1, 13):
    try:
        Phone = driver.find_element_by_xpath(
            '//*[@id="container"]/div[2]/div/div[2]/div[2]/div[' + str(i) + "]/div/h4/a"
        )
        PhoneName = str(Phone.text)
        PhoneName = PhoneName.split("\n")
        Phones["itel"][PhoneName[1]] = Phone.get_attribute("href")
        # print((PhoneName[1], Phone.get_attribute("href")))
    except:
        1 == 1
        # print(i)

# %%
driver.close()

# %%
# for j in range(len(Phones)):

# df = pd.read_html(Phones['Apple']['iphone 6'].get_attribute("href"))
#     new = df[0]
# new.insert(0, "Phone", Phones[0].text, True)
# new.set_index(["Phone", 0, 1], inplace=True)
SpecsDF = pd.read_html(Phones["Huawei"]["Mate 20 Pro"])

SpecsDF[0].drop(columns=[3], inplace=True)
#     DataFrames.append(new)
# print(df)
# SpecsDF[0]
# Phones.clear()

# %%
Phones
# Out:
# {}

# %%
SpecList = list()
Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
SubDict = dict()

for i in range(0, Build.shape[0]):
    SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]
BuildDict = SubDict
Set = ("Build", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Frequency.shape[0]):
    SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
FreDict = SubDict
Set = ("Frequency", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Processor.shape[0]):
    SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
ProDict = SubDict
Set = ("Processor", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Display.shape[0]):
    SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
DisDict = SubDict
Set = ("Display", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Memory.shape[0]):
    SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
MemDict = SubDict
Set = ("Memory", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Camera.shape[0]):
    SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
CamDict = SubDict
Set = ("Camera", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Connectivity.shape[0]):
    SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
ConDict = SubDict
Set = ("Connectivity", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Features.shape[0]):
    SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
FeatDict = SubDict
Set = ("Features", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Battery.shape[0]):
    SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
BatDict = SubDict
Set = ("Battery", SubDict)
SpecList.append(Set)

# %%
FeatDict
# Out:
# {'Sensors': 'Accelerometer, Barometer, Compass, Face ID, Fingerprint (Under display), Gyro, Proximity',
#  'Audio': 'Type-C to 3.5 mm headphone jack adapter, 32-bit/384kHz audio, MP3/eAAC+/WAV/Flac player, DivX/XviD/MP4/H.265/WMV player, Speaker Phone',
#  'Browser': 'HTML5',
#  'Messaging': 'SMS(threaded view), MMS, Email, Push Mail, IM',
#  'Games': 'Built-in + Downloadable',
#  'Torch': 'Yes',
#  'Extra': 'Front/back glass + aluminum frame, IP68 dust/water resistant (up to 2m for 30 mins), Active noise cancellation with dedicated mic, Document viewer, Photo/video editor'}

# %%
for key in Phones["Huawei"]:

    SpecsDF = pd.read_html(Phones["Huawei"][key])

    SpecsDF[0].drop(columns=[3], inplace=True)
    SpecList = list()
    Build = SpecsDF[0].loc[df[0][0] == "Build"]
    Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
    Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
    Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
    Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
    Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
    Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
    Features = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
    Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
    SubDict = dict()

    for i in range(0, Build.shape[0]):
        SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]
    Set = ("Build", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Frequency.shape[0]):
        SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
    Set = ("Frequency", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Processor.shape[0]):
        SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
    Set = ("Processor", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Display.shape[0]):
        SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
    Set = ("Display", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Memory.shape[0]):
        SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
    Set = ("Memory", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Camera.shape[0]):
        SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
    Set = ("Camera", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Connectivity.shape[0]):
        SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
    Set = ("Connectivity", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Features.shape[0]):
        SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
    Set = ("Features", SubDict)
    SpecList.append(Set)
    SubDict = dict()
    for i in range(0, Battery.shape[0]):
        SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
    Set = ("Battery", SubDict)
    SpecList.append(Set)

# %%
BuildList = list(Build)

# %%
BuildList
# Out:
# [0, 1, 2]

# %%
SpecList = list()
Build = SpecsDF[0].loc[df[0][0] == "Build"]
Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
Features = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
SubDict = dict()

for i in range(0, Build.shape[0]):
    SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]

Set = ("Build", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Frequency.shape[0]):
    SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
Set = ("Frequency", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Processor.shape[0]):
    SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
Set = ("Processor", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Display.shape[0]):
    SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
Set = ("Display", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Memory.shape[0]):
    SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
Set = ("Memory", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Camera.shape[0]):
    SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
Set = ("Camera", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Connectivity.shape[0]):
    SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
Set = ("Connectivity", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Features.shape[0]):
    SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
Set = ("Features", SubDict)
SpecList.append(Set)
SubDict = dict()
for i in range(0, Battery.shape[0]):
    SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
Set = ("Battery", SubDict)
SpecList.append(Set)

# %%
# SubDict
# SpecList
# type(Set)
# Out:
# [('Build',
#   {'OS': 'Android 9.0 (Pie)',
#    'UI': 'EMUI 9.0',
#    'Dimensions': '157.8 x 72.3 x 8.6 mm',
#    'Weight': '189 g',
#    'SIM': 'Dual Sim, Dual Standby (Nano-SIM)',
#    'Colors': 'Emerald Green, Midnight Blue, Twilight, Pink Gold, Black'}),
#  ('Frequency',
#   {'2G Band': 'SIM1: GSM 850 / 900 / 1800 / 1900SIM2: GSM 850 / 900 / 1800 / 1900',
#    '3G Band': 'HSDPA 850 / 900 / 1900 / 2100',
#    '4G Band': 'LTE band 1(2100), 2(1900), 3(1800), 4(1700/2100), 5(850), 6(900), 7(2600), 8(900), 9(1800), 12(700), 17(700), 18(800), 19(800), 20(800), 26(850), 28(700), 32(1500), 34(2000), 38(2600), 39(1900), 40(2300)'}),
#  ('Processor',
#   {'CPU': 'Octa-core (2 x 2.6 GHz Cortex-A76 + 2 x 1.92 GHz Cortex-A76 + 4 x 1.8 GHz Cortex-A55)',
#    'Chipset': 'HiSilicon Kirin 980 (7 nm)',
#    'GPU': 'Mali-G76 MP10'}),
#  ('Display',
#   {'Technology': 'AMOLED Capacitive Touchscreen, 16M Colors, Multitouch',
#    'Size': '6.4 Inches',
# ...

# %%
collection = db.collection("Specifications")

# %%
for item in SpecList:
    try:
        collection.document(item[0]).set(item[1])
    except:
        print(item[1])

# %%
for key in SubDict:
    print(type(key))
# Out:
# <class 'str'>
# <class 'str'>

# %%
for i in range(len(df)):
    if re.search("iphone", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }

        db.collection(u"MobileProduct/BrandName/Apple").add(data)

    elif re.search("samsung", df["Name"][i], flags=re.IGNORECASE):

        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }

        db.collection(u"MobileProduct/BrandName/Samsung").add(data)

    elif re.search("huawei", df["Name"][i], flags=re.IGNORECASE):

        for phone in Phones["Huawei"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                SpecsDF = pd.read_html(Phones["Huawei"][phone])
                SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for i in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]
                Set = ("Build", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
                Set = ("Frequency", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
                Set = ("Processor", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
                Set = ("Display", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
                Set = ("Memory", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
                Set = ("Camera", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
                Set = ("Connectivity", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
                Set = ("Features", SubDict)
                SpecList.append(Set)
                SubDict = dict()
                for i in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
                Set = ("Battery", SubDict)
                SpecList.append(Set)
                data = {
                    u"MobileID": i,
                    u"MobileName": df["Name"][i],
                    u"Price": df["Price"][i],
                    u"Vendor": df["Vendor"][i],
                    u"VendorLink": df["VendorLink"][i],
                    u"Build": BuildDict,
                }
                db.collection(u"MobileProduct/BrandName/Huawei").add(data)

                #                 String id = db.collection("collection_name").document().getId();
                #                 db.collection("collection_name").document(id).set(object);

                #                 for item in SpecList:
                #                     try:
                #                         db.collection(u"MobileProduct/BrandName/Huawei/Specifications").document(item[0]).set(item[1])
                #                     except:
                #                         print(item[1])
                break
            else:
                data = {
                    u"MobileID": i,
                    u"MobileName": df["Name"][i],
                    u"Price": df["Price"][i],
                    u"Vendor": df["Vendor"][i],
                    u"VendorLink": df["VendorLink"][i],
                }
                db.collection(u"MobileProduct/BrandName/Huawei").add(data)

    elif re.search("vivo", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Vivo").add(data)

    elif re.search("oppo", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Oppo").add(data)

    elif re.search("realme", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Realme").add(data)

    elif re.search("nokia", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Nokia").add(data)

    elif re.search("xiaomi", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Xiaomi").add(data)

    elif re.search("infinix", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Infinix").add(data)

    elif re.search("Tecno", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Tecno").add(data)

    elif re.search("qmobile", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Qmobile").add(data)

    elif re.search("lenovo", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Lenovo").add(data)

    elif re.search("sony", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Sony").add(data)

    elif re.search("LG", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/LG").add(data)

    elif re.search("itel", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/itel").add(data)

    elif re.search("Oneplus", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/OnePlus").add(data)

    elif re.search("Telenor", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Telenor").add(data)

    elif re.search("Alcatel", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Alcatel").add(data)

    elif re.search("HTC", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/HTC").add(data)

    elif re.search("Moto", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Motorola").add(data)

    elif re.search("Calme", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Calme").add(data)

    elif re.search("gfive", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/GFive").add(data)

    else:
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Other").add(data)
# Out:
# {'OS': 'Android 10 OS', 'UI': 'EMUI 10', 'Dimensions': '159.2 x 76.3 x 8.7 mm', 'Weight': '183 g', 'SIM': 'Dual Sim, Dual Standby (Nano-SIM)', 'Colors': 'Skyline grey, Midnight Black, Crush Green, Sakura Pink'}
# {'2G Band': 'SIM1: GSM 850 / 900 / 1800 / 1900SIM2: GSM 850 / 900 / 1800 / 1900', '3G Band': 'HSDPA 850 / 900 / 2100', '4G Band': 'LTE band 1(2100), 3(1800), 5(850), 8(900), 38(2600), 39(1900), 40(2300), 41(2500)'}
# {'CPU': 'Octa-core (2 x 2.27 GHz Cortex-A76 + 6 x 1.88 GHz Cortex-A55)', 'Chipset': 'HiSilicon Kirin 810 (7 nm)', 'GPU': 'Mali-G52 MP6'}
# {'Technology': 'LTPS IPS LCD Capacitive Touchscreen, 16M Colors, Multitouch', 'Size': '6.4 Inches', 'Resolution': '1080 x 2310 Pixels (~398 PPI)', 'Protection': 'Corning Gorilla Glass'}
# {'Built-in': '128GB Built-in, 8GB RAM, UFS 2.1', 'Card': 'Nano Memory Card, (supports up to 256GB) (uses shared SIM slot)'}
# ...

# %%
BuildDict
# Out:
# {'OS': 'Android 10 OS',
#  'UI': 'EMUI 10',
#  'Dimensions': '159.2 x 76.3 x 8.7 mm',
#  'Weight': '183 g',
#  'SIM': 'Dual Sim, Dual Standby (Nano-SIM)',
#  'Colors': 'Skyline grey, Midnight Black, Crush Green, Sakura Pink'}

# %%
for i in range(len(df)):
    if re.search("iphone", df["Name"][i], flags=re.IGNORECASE):
        data = {
            u"MobileID": i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }

        db.collection(u"MobileProduct/BrandName/Apple").add(data)

    elif re.search("huawei", df["Name"][i], flags=re.IGNORECASE):

        for phone in Phones["Huawei"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 SpecsDF = pd.read_html(Phones["Huawei"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                #                 SpecList = list()
                #                 Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                #                 Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                #                 Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                #                 Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                #                 Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                #                 Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                #                 Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                #                 Features = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                #                 Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                #                 SubDict = dict()

                #                 for i in range(0, Build.shape[0]):
                #                     SubDict[str(Build.iat[i, 1])] = Build.iat[i, 2]
                #                 Set = ("Build", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Frequency.shape[0]):
                #                     SubDict[str(Frequency.iat[i, 1])] = Frequency.iat[i, 2]
                #                 Set = ("Frequency", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Processor.shape[0]):
                #                     SubDict[str(Processor.iat[i, 1])] = Processor.iat[i, 2]
                #                 Set = ("Processor", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Display.shape[0]):
                #                     SubDict[str(Display.iat[i, 1])] = Display.iat[i, 2]
                #                 Set = ("Display", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Memory.shape[0]):
                #                     SubDict[str(Memory.iat[i, 1])] = Memory.iat[i, 2]
                #                 Set = ("Memory", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Camera.shape[0]):
                #                     SubDict[str(Camera.iat[i, 1])] = Camera.iat[i, 2]
                #                 Set = ("Camera", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Connectivity.shape[0]):
                #                     SubDict[str(Connectivity.iat[i, 1])] = Connectivity.iat[i, 2]
                #                 Set = ("Connectivity", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Features.shape[0]):
                #                     SubDict[str(Features.iat[i, 1])] = Features.iat[i, 2]
                #                 Set = ("Features", SubDict)
                #                 SpecList.append(Set)
                #                 SubDict = dict()
                #                 for i in range(0, Battery.shape[0]):
                #                     SubDict[str(Battery.iat[i, 1])] = str(Battery.iat[i, 2])
                #                 Set = ("Battery", SubDict)
                #                 SpecList.append(Set)
                data = {
                    u"MobileID": i,
                    u"MobileName": df["Name"][i],
                    u"Price": df["Price"][i],
                    u"Vendor": df["Vendor"][i],
                    u"VendorLink": df["VendorLink"][i],
                    u"Build": BuildDict,
                }
                db.collection(u"MobileProduct/BrandName/Huawei").add(data)

#                 String id = db.collection("collection_name").document().getId();
#                 db.collection("collection_name").document(id).set(object);

#                 for item in SpecList:
#                     try:
#                         db.collection(u"MobileProduct/BrandName/Huawei/Specifications").document(item[0]).set(item[1])
#                     except:
#                         print(item[1])
#                 break
#             else:
#                 data = {
#                     u"MobileID":  i,
#                     u"MobileName": df["Name"][i],
#                     u"Price": df["Price"][i],
#                     u"Vendor": df["Vendor"][i],
#                     u"VendorLink": df["VendorLink"][i],
#                 }
#                 db.collection(u"MobileProduct/BrandName/Huawei").add(data)

# %%
for i in range(len(df)):
    if re.search("huawei", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Huawei"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Huawei"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection("MobileProduct/BrandName/Huawei").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection("MobileProduct/BrandName/Huawei").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break

# %%
# df
# Phones["Huawei"]
# Out:
# {'P30 Pro': 'https://www.whatmobile.com.pk/Huawei_P30-Pro',
#  'Mate 20 Pro': 'https://www.whatmobile.com.pk/Huawei_Mate-20-Pro',
#  'P20 Pro': 'https://www.whatmobile.com.pk/Huawei_P20-Pro',
#  'P30': 'https://www.whatmobile.com.pk/Huawei_P30',
#  'Y9a': 'https://www.whatmobile.com.pk/Huawei_Y9a',
#  'Nova 7i': 'https://www.whatmobile.com.pk/Huawei_Nova-7i',
#  'Y9s 2019': 'https://www.whatmobile.com.pk/Huawei_Y9s-2019',
#  'P30 Lite': 'https://www.whatmobile.com.pk/Huawei_P30-Lite',
#  'Nova 3i': 'https://www.whatmobile.com.pk/Huawei_Nova-3i',
#  'Y7a': 'https://www.whatmobile.com.pk/Huawei_Y7a',
#  'Y9 Prime 2019': 'https://www.whatmobile.com.pk/Huawei_Y9-Prime-2019',
#  'Y8p': 'https://www.whatmobile.com.pk/Huawei_Y8p',
#  'Watch GT': 'https://www.whatmobile.com.pk/Huawei_Watch-GT',
#  'Y7p': 'https://www.whatmobile.com.pk/Huawei_Y7p',
#  'MediaPad T3 10': 'https://www.whatmobile.com.pk/Huawei_MediaPad-T3-10',
# ...

# %%
s1 = "Nova 7i"
s2 = "Huawei Y6s (2019) - (64GB) :1Y"
s12 = s1.split(" ")
for word in s12:
    if word not in s2:
        SameCheck = False
if SameCheck == True:
    print(f"SameCheck is True for --{s1}-- and --{s2}")

# %%
for i in range(len(df)):
    print(f'i = {i}')
    if re.search("iphone", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Apple"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Apple"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Apple").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Apple").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("samsung", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Samsung"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Samsung"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Samsung").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Samsung").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("huawei", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Huawei"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Huawei"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Huawei").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Huawei").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("vivo", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Vivo"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Vivo"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Vivo").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Vivo").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("oppo", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["OPPO"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["OPPO"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Oppo").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Oppo").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("realme", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Realme"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Realme"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Realme").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Realme").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("nokia", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Nokia"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Nokia"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Nokia").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Nokia").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break+         

    elif re.search("xiaomi", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Xiaomi"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Xiaomi"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Xiaomi").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Xiaomi").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("infinix", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Infinix"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Infinix"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Infinix").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
#             db.collection("MobileProduct/BrandName/Huawei").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            db.collection(u"MobileProduct/BrandName/Infinix").add(data)
         

    elif re.search("Tecno", df["Name"][i], flags=re.IGNORECASE):
         for phone in Phones["Tecno"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Tecno"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Tecno").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

            if SameCheck == False:
                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                }
                db.collection(u"MobileProduct/BrandName/Tecno").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break        

    elif re.search("qmobile", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["QMobile"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["QMobile"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/QMobile").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/QMobile").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("lenovo", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Lenovo"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Lenovo"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Lenovo").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Lenovo").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("sony", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Sony"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Sony"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Sony").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Sony").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("LG", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["LG"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["LG"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/LG").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/LG").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("itel", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["itel"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["itel"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Itel").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Itel").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("Oneplus", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["OnePlus"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["OnePlus"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/OnePlus").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/OnePlus").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("Telenor", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Telenor"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Telenor"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Telenor").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Telenor").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("Alcatel", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Alcatel"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Alcatel"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Alcatel").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Alcatel").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("HTC", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["HTC"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["HTC"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/HTC").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/HTC").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("Moto", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Motorola"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Motorola"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Motorola").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Motorola").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         
    elif re.search("Calme", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["Calme"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["Calme"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/Calme").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/Calme").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         

    elif re.search("gfive", df["Name"][i], flags=re.IGNORECASE):
        for phone in Phones["G'Five"]:
            s = phone.split(" ")
            SameCheck = True
            for word in s:
                if word not in df["Name"][i]:
                    SameCheck = False
            if SameCheck == True:
                #                 print(f'SameCheck is True for --{phone}-- and --{df["Name"][i]}' )
                SpecsDF = pd.read_html(Phones["G'Five"][phone])
                #                 SpecsDF[0].drop(columns=[3], inplace=True)

                SpecList = list()
                Build = SpecsDF[0].loc[SpecsDF[0][0] == "Build"]
                Frequency = SpecsDF[0].loc[SpecsDF[0][0] == "Frequency"]
                Processor = SpecsDF[0].loc[SpecsDF[0][0] == "Processor"]
                Display = SpecsDF[0].loc[SpecsDF[0][0] == "Display"]
                Memory = SpecsDF[0].loc[SpecsDF[0][0] == "Memory"]
                Camera = SpecsDF[0].loc[SpecsDF[0][0] == "Camera"]
                Connectivity = SpecsDF[0].loc[SpecsDF[0][0] == "Connectivity"]
                Features = SpecsDF[0].loc[SpecsDF[0][0] == "Features"]
                Battery = SpecsDF[0].loc[SpecsDF[0][0] == "Battery"]
                SubDict = dict()

                for j in range(0, Build.shape[0]):
                    SubDict[str(Build.iat[j, 1])] = Build.iat[j, 2]
                BuildDict = SubDict
                SubDict = dict()
                for j in range(0, Frequency.shape[0]):
                    SubDict[str(Frequency.iat[j, 1])] = Frequency.iat[j, 2]
                FreDict=SubDict
                 
                SubDict = dict()
                for j in range(0, Processor.shape[0]):
                    SubDict[str(Processor.iat[j, 1])] = Processor.iat[j, 2]
                
                ProcDict=SubDict
                SubDict = dict()
                for j in range(0, Display.shape[0]):
                    SubDict[str(Display.iat[j, 1])] = Display.iat[j, 2]
                
                DisDict=SubDict 
                SubDict = dict()
                for j in range(0, Memory.shape[0]):
                    SubDict[str(Memory.iat[j, 1])] = Memory.iat[j, 2]
                MemDict=SubDict
                SubDict = dict()
                for j in range(0, Camera.shape[0]):
                    SubDict[str(Camera.iat[j, 1])] = Camera.iat[j, 2]
                CamDict=SubDict 
                SubDict = dict()
                for j in range(0, Connectivity.shape[0]):
                    SubDict[str(Connectivity.iat[j, 1])] = Connectivity.iat[j, 2]
                ConDict=SubDict 
                SubDict = dict()
                for j in range(0, Features.shape[0]):
                    SubDict[str(Features.iat[j, 1])] = Features.iat[j, 2]
                FeatDict=SubDict 
                SubDict = dict()
                for j in range(0, Battery.shape[0]):
                    SubDict[str(Battery.iat[j, 1])] = str(Battery.iat[j, 2])
                BatDict=SubDict 

                data = {
                    "MobileID": i,
                    "MobileName": df["Name"][i],
                    "Price": df["Price"][i],
                    "Vendor": df["Vendor"][i],
                    "VendorLink": df["VendorLink"][i],
                    "Build": BuildDict,
                    "Frequency":FeatDict,
                    "Processor":ProcDict,
                    "Display":DisDict,
                    "Memory":MemDict,
                    "Camera":CamDict,
                    "Connectivity":ConDict,
                    "Features":FeatDict,
                    "Battery":BatDict,
                    
                }
                db.collection(u"MobileProduct/BrandName/GFive").add(data)
#                 print(f'SameCheck is True for i={i} --{phone}-- and --{df["Name"][i]}--')
                break

        if SameCheck == False:
            data = {
                "MobileID": i,
                "MobileName": df["Name"][i],
                "Price": df["Price"][i],
                "Vendor": df["Vendor"][i],
                "VendorLink": df["VendorLink"][i],
            }
            db.collection(u"MobileProduct/BrandName/GFive").add(data)
#             print(f'SameCheck is False for i={i} --{phone}-- and --{df["Name"][i]}--')
            #break         
    else:
        data = {
            u"MobileID":  i,
            u"MobileName": df["Name"][i],
            u"Price": df["Price"][i],
            u"Vendor": df["Vendor"][i],
            u"VendorLink": df["VendorLink"][i],
        }
        db.collection(u"MobileProduct/BrandName/Other").add(data)
# Out:
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4
# i = 5
# i = 6
# i = 7
# i = 8
# i = 9
# i = 10
# i = 11
# i = 12
# i = 13
# i = 14
# i = 15
# i = 16
# i = 17
# i = 18
# i = 19
# i = 20
# i = 21
# i = 22
# i = 23
# i = 24
# i = 25
# i = 26
# i = 27
# i = 28
# i = 29
# i = 30
# i = 31
# i = 32
# i = 33
# i = 34
# i = 35
# i = 36
# i = 37
# i = 38
# i = 39
# i = 40
# i = 41
# i = 42
# i = 43
# i = 44
# i = 45
# i = 46
# i = 47
# i = 48
# i = 49
# i = 50
# i = 51
# i = 52
# i = 53
# i = 54
# i = 55
# i = 56
# i = 57
# i = 58
# i = 59
# i = 60
# i = 61
# i = 62
# i = 63
# i = 64
# i = 65
# i = 66
# i = 67
# i = 68
# i = 69
# i = 70
# i = 71
# i = 72
# i = 73
# i = 74
# i = 75
# i = 76
# i = 77
# i = 78
# i = 79
# i = 80
# i = 81
# i = 82
# i = 83
# i = 84
# i = 85
# i = 86
# i = 87
# i = 88
# i = 89
# i = 90
# i = 91
# i = 92
# i = 93
# i = 94
# i = 95
# i = 96
# i = 97
# i = 98
# i = 99
# i = 100
# i = 101
# i = 102
# i = 103
# i = 104
# i = 105
# i = 106
# i = 107
# i = 108
# i = 109
# i = 110
# ...

# %%
Phones
# Out:
# {'Samsung': {'Galaxy Z Fold 2': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Fold-2',
#   'Galaxy Z Flip': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Z-Flip',
#   'Galaxy S20 Ultra': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20-Ultra',
#   'Galaxy Note 20 Ultra': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-20-Ultra',
#   'Galaxy S21 Ultra': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21-Ultra',
#   'Galaxy Note 10 Plus': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-10-Plus',
#   'Galaxy S20 Plus': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20-Plus',
#   'Galaxy S21 Plus': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21-Plus',
#   'Galaxy Note 20': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-20',
#   'Galaxy S20': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S20',
#   'Galaxy Note 10': 'https://www.whatmobile.com.pk/Samsung_Galaxy-Note-10',
#   'Galaxy S21': 'https://www.whatmobile.com.pk/Samsung_Galaxy-S21',
# ...
