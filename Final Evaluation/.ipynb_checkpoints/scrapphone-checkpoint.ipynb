# %%
import bs4 as bs
import re
import pandas as pd
from selenium import webdriver
name=[]
price=[]
url = 'https://homeshopping.pk/categories/Mobile-Phones-Price-Pakistan'

driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
for j in range(1,21):
    driver.execute_script("window.scrollTo(0, 300)")
    ++j
    for i in range(1,25):
        target_name=driver.find_element_by_xpath('/html/body/div[1]/div[9]/div[2]/div[2]/div[5]/div/div['+str(i)+']/div/h5/a')
        target_prize=driver.find_element_by_xpath('/html/body/div[1]/div[9]/div[2]/div[2]/div[5]/div/div['+str(i)+']/div/div[2]/a/div')
        name.append(target_name.text)
        price.append(target_prize.text)

driver.close()

# %%
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
#      index                                               Name      Price
# 0        2        Apple iPhone 11 (4G, 64GB ,Black) - Non PTA  Rs 99,999
# 1       26        Apple iPhone 11 (4G, 64GB ,Black) - Non PTA  Rs 99,999
# 2       50        Apple iPhone 11 (4G, 64GB ,Black) - Non PTA  Rs 99,999
# 3       74        Apple iPhone 11 (4G, 64GB ,Black) - Non PTA  Rs 99,999
# 4       98        Apple iPhone 11 (4G, 64GB ,Black) - Non PTA  Rs 99,999
# ..     ...                                                ...        ...
# 475    380  Vivo Y20s (4G 4GB 128GB Purist Blue) With Offi...  Rs 26,999
# 476    404  Vivo Y20s (4G 4GB 128GB Purist Blue) With Offi...  Rs 26,999
# 477    428  Vivo Y20s (4G 4GB 128GB Purist Blue) With Offi...  Rs 26,999
# 478    452  Vivo Y20s (4G 4GB 128GB Purist Blue) With Offi...  Rs 26,999
# 479    476  Vivo Y20s (4G 4GB 128GB Purist Blue) With Offi...  Rs 26,999
#
# [480 rows x 3 columns]

# %%
import bs4 as bs
import re
import pandas as pd
from selenium import webdriver
name=[]
price=[]
url = 'https://www.telemart.pk/mobile-and-tablets-deals.html'

driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
#for j in range(2,6):
 #   page=driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/div[3]/div/div[2]/div[2]/div/div/ul/li['+str(j)+']/a')
  #  driver.get(page.get_attribute("onclick"))
    

for i in range(1,48):
    target_name=driver.find_element_by_xpath('//*[@id="result"]/div[1]/div['+str(i)+']/a/div[2]/h2/span')
    target_prize=driver.find_element_by_xpath('//*[@id="result"]/div[1]/div['+str(i)+']/a/div[2]/div[2]/ins')
    name.append(target_name.text)
    price.append(target_prize.text)


driver.close()
#print(name)
#print(price)
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
#     index                                               Name       Price
# 0      39  ASUS ROG Phone 3 SD865+, 5G - ZS661KS Dual-SIM...  Rs.139,499
# 1      12  Apple iPhone 12 128GB (Single SIM + eSIM PTA A...  Rs.179,999
# 2       7  Apple iPhone 12 256GB (Single SIM + eSIM PTA A...  Rs.195,499
# 3      11  Apple iPhone 12 64GB (Single SIM + eSIM PTA Ap...  Rs.168,499
# 4      13  Apple iPhone 12 Pro 128GB (Single SIM + eSIM P...  Rs.203,999
# 5      32  Apple iPhone 12 Pro 24kt Gold Plated (With Aut...  Rs.397,999
# 6      14  Apple iPhone 12 Pro 256GB (Single SIM + eSIM P...  Rs.215,999
# 7      15  Apple iPhone 12 Pro 512GB (Single SIM + eSIM P...  Rs.240,499
# 8      16  Apple iPhone 12 Pro Max 128GB (Single SIM + eS...  Rs.219,499
# 9      10  Apple iPhone 12 Pro Max 24kt Gold Plated (With...  Rs.413,999
# 10     17  Apple iPhone 12 Pro Max 256GB (Single SIM + eS...  Rs.232,499
# 11     18  Apple iPhone 12 Pro Max 512GB (Single SIM + eS...  Rs.266,999
# ...

# %%
import bs4 as bs
import re
import pandas as pd
from selenium import webdriver
name=[]
price=[]
url = 'https://www.symbios.pk/smart-phones'

driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
for i in range(1,119):
    target_name=driver.find_element_by_xpath('/html/body/div[4]/div/div/div[2]/div[4]/div/div/div/div/div[1]/div['+str(i)+']/div/div/div[2]/h3/a')
    target_prize=driver.find_element_by_xpath('/html/body/div[4]/div/div/div[2]/div[4]/div/div/div/div/div[1]/div['+str(i)+']/div/div/div[2]/div[3]/span[1]')
    name.append(target_name.text)
    price.append(target_prize.text)


driver.close()
#print(name)
#print(price)
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
#      index                               Name       Price
# 0      117         Apple USB Power Adapter...    Rs.3,299
# 1       73  Apple iPhone 8 Plus 256GB Slig...   Rs.75,999
# 2       75  Apple iPhone SE 2020 128GB Sin...  Rs.108,999
# 3       76  Apple iPhone SE 2020 256GB Sin...  Rs.145,899
# 4       77  Apple iPhone SE 2020 64GB Sing...   Rs.99,549
# ..     ...                                ...         ...
# 113     65  infinix hot 10 X682c 4GB, 128G...   Rs.22,999
# 114     64  infinix hot 10 X682c 6GB, 128G...   Rs.24,999
# 115     66  infinix hot 10 play X682B 4GB,...   Rs.20,999
# 116     63  infinix note 8 6GB, 128GB Buil...   Rs.29,999
# 117     62  infinix note 8i 6GB, 128GB Bui...   Rs.26,999
#
# [118 rows x 3 columns]

# %%
import bs4 as bs
import re
import pandas as pd
from selenium import webdriver
name=[]
price=[]
url = 'https://myshop.pk/mobiles-smartphones-tablets/smartphones?a_product_type=969&product_list_limit=64&product_list_order=name'

driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
for i in range(1,64):
    if i==8 or i==10 or i==11 or i==14 or i==17 or i==20 or i==58:
        ++i
    elif i>60:
        target_name=driver.find_element_by_xpath('/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li['+str(i)+']/div/div[2]/strong/a')
        target_prize=driver.find_element_by_xpath('/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li['+str(i)+']/div/div[2]/div[4]/span/span/span[2]/span')
        name.append(target_name.text)
        price.append(target_prize.text)
    else:
        target_name=driver.find_element_by_xpath('/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li['+str(i)+']/div/div[2]/strong/a')
        target_prize=driver.find_element_by_xpath('/html/body/div[1]/main/div[3]/div[1]/div[3]/ol/li['+str(i)+']/div/div[2]/div[4]/span/span/span')
        name.append(target_name.text)
        price.append(target_prize.text)

driver.close()
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
#     index                                               Name          Price
# 0       0                          Apple iPhone 12 Pro 128GB  Rs 197,900.00
# 1       1                          Apple iPhone 12 Pro 256GB  Rs 205,900.00
# 2       2                          Apple iPhone 12 Pro 512GB  Rs 229,900.00
# 3       3                      Apple iPhone 12 Pro Max 128GB  Rs 194,900.00
# 4       4                      Apple iPhone 12 Pro Max 256GB  Rs 207,900.00
# 5       5                      Apple iPhone 12 Pro Max 512GB  Rs 249,900.00
# 6       6                Apple | iPhone 11 - 128 GB Dual Sim  Rs 129,500.00
# 7       7                 Apple | iPhone 11 - 64 GB Dual Sim  Rs 119,500.00
# 8       8           Apple | iPhone 11 Pro - 256GB Single Sim  Rs 192,500.00
# 9       9      Apple | iPhone 11 Pro - 512 GB Single Sim :1Y
# 10     10            Apple | iPhone 11 Pro - 64GB Single Sim  Rs 171,500.00
# 11     11      Apple | iPhone 11 Pro Max - 256 GB Single Sim  Rs 213,500.00
# ...

# %%
import bs4 as bs
import re
import pandas as pd
from selenium import webdriver
name=[]
price=[]
url = 'https://www.zaibis.com/product-category/new-mobile-phones/'

driver = webdriver.Chrome('C:/Users/Usman/Downloads/chromedriver.exe')
driver.get(url)
for j in range(1,11):
    driver.get('https://www.zaibis.com/product-category/new-mobile-phones/page/'+str(j)+'/')
    for i in range(1,32):
        target_name=driver.find_element_by_xpath('/html/body/div[2]/div/div[3]/div/div/div[1]/main/ul/li['+str(i)+']/div/div/div[1]/a/h2')
        target_prize=driver.find_element_by_xpath('//*[@id="main"]/ul/li['+str(i)+']/div/div/div[3]/div[1]/span')
        name.append(target_name.text)
        price.append(target_prize.text)


driver.close()
#print(name)
#print(price)
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
#      index                                               Name  \
# 0       90                    Alcatel 1S (3Gb/32Gb) (BoxPack)
# 1       88                   Alcatel 1SE (4Gb/64Gb) (BoxPack)
# 2       89                    Alcatel 3x (4Gb/64Gb) (BoxPack)
# 3       16                                        Alcatel A30
# 4       68                     Apple IPhone 7 128GB RED (NEW)
# ..     ...                                                ...
# 305     15     iPhone Xs Max 256GB Dual Gold,Sliver (BoxPack)
# 306     14            iPhone Xs Max 512GB Dual Grey (BoxPack)
# 307    244  iPhone Xs Max Dual 64GB Gold,Grey,Sliver (BoxP...
# 308     91                      vivo Y11 (2GB/32GB) (BoxPack)
# 309    163                      vivo Y11 (3GB/32GB) (BoxPack)
#
#                       Price
# 0                ₨15,999.00
# 1                ₨18,499.00
# 2                ₨19,999.00
# 3    ₨10,000.00\n₨11,500.00
# 4    ₨82,500.00\n₨83,999.00
# ..                      ...
# ...

# %%
import pandas as pd
from selenium import webdriver
Names=[]
Prices=[]
driver = webdriver.Chrome("C:/Users/Usman/Downloads/chromedriver.exe")

for i in range(1,80):
#     page=driver.find_element_by_xpath('/html/body/div[3]/div/div[3]/div[1]/div/div[1]/div[3]/div/ul/li[9]/a')
#     driver.get(page.get_attribute("href"))
    driver.get("https://www.daraz.pk/smartphones/?page="+str(i))
    for j in range(1,40):
        Name=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['+ str(j)+ "]/div/div/div[2]/div[2]/a")
        Price=driver.find_element_by_xpath('//*[@id="root"]/div/div[3]/div[1]/div/div[1]/div[2]/div['+ str(j)+ "]/div/div/div[2]/div[3]/span")
        Names.append(Name.text)
        Prices.append(Price.text)
driver.close()
df=pd.DataFrame(list(zip(name,price)),columns=["Name","Price"])
df.sort_values(["Name","Price"],inplace=True)
df.reset_index(0,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# ...
